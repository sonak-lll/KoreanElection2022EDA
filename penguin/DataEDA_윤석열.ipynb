# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib
import matplotlib_inline
import seaborn as sns
from wordcloud import WordCloud
import matplotlib.font_manager as fm
import collections
from collections import Counter

# %%
from konlpy.tag import Mecab

# %%
plt.rc('font', family='NanumGothic') # For Windows
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
df1 = pd.read_csv('./CrawledData/윤석열/윤석열_2022-02-09~2022-02-16_result.csv',encoding='utf-8')
df2 = pd.read_csv('./CrawledData/윤석열/윤석열_2022-02-16~2022-02-23_result.csv',encoding='utf-8')
df3 = pd.read_csv('./CrawledData/윤석열/윤석열_2022-02-23~2022-03-02_result.csv',encoding='utf-8')
df4 = pd.read_csv('./CrawledData/윤석열/윤석열_2022-03-02~2022-03-09_result.csv',encoding='utf-8')

# %%
df = pd.read_csv('./CrawledData/윤석열/윤석열_2022-02-09~2022-03-09_result.csv',encoding='utf-8')

# %%
dfs = [df1, df2, df3, df4]

# %%
n=1
for i in dfs:
    print('{}주차 윤석열 데이터 개수: {}'.format(n, len(i['text'])))
    n = n+1
# Out:
# 1주차 윤석열 데이터 개수: 6952
# 2주차 윤석열 데이터 개수: 6939
# 3주차 윤석열 데이터 개수: 6964
# 4주차 윤석열 데이터 개수: 6990

# %%
#긍정 1, 부정 0
print('2022-02-09~2022-02-16 긍정 리뷰 갯수: {}'.format(df1['label'].value_counts()[1]))
print('2022-02-09~2022-02-16 부정 리뷰 갯수: {}'.format(df1['label'].value_counts()[0]))
print('2022-02-16~2022-02-23 긍정 리뷰 갯수: {}'.format(df2['label'].value_counts()[1]))
print('2022-02-16~2022-02-23 부정 리뷰 갯수: {}'.format(df2['label'].value_counts()[0]))
print('2022-02-23~2022-03-02 긍정 리뷰 갯수: {}'.format(df3['label'].value_counts()[1]))
print('2022-02-23~2022-03-02 부정 리뷰 갯수: {}'.format(df3['label'].value_counts()[0]))
print('2022-03-02~2022-03-09 긍정 리뷰 갯수: {}'.format(df4['label'].value_counts()[1]))
print('2022-03-02~2022-03-09 부정 리뷰 갯수: {}'.format(df4['label'].value_counts()[0]))
# Out:
# 2022-02-09~2022-02-16 긍정 리뷰 갯수: 1907
# 2022-02-09~2022-02-16 부정 리뷰 갯수: 5045
# 2022-02-16~2022-02-23 긍정 리뷰 갯수: 2030
# 2022-02-16~2022-02-23 부정 리뷰 갯수: 4909
# 2022-02-23~2022-03-02 긍정 리뷰 갯수: 2141
# 2022-02-23~2022-03-02 부정 리뷰 갯수: 4823
# 2022-03-02~2022-03-09 긍정 리뷰 갯수: 1907
# 2022-03-02~2022-03-09 부정 리뷰 갯수: 5083

# %% [markdown]
# ### 긍정, 부정 분포 확인

# %%
# 주차별 긍정 부정 갯수 확인용
pos = []
for i in dfs:
    if i['label'].value_counts()[1]:
        pos.append(i['label'].value_counts()[1])
neg = []
for i in dfs:
    if i['label'].value_counts()[0]:
        neg.append(i['label'].value_counts()[0])

# %%
label = ['1주차', '2주차', '3주차', '4주차']
week = pd.DataFrame({'pos':pos, 'neg':neg}, index=label)
week.plot.bar(color=['r', 'b'], width=0.8, title='윤석열 주차별 레이블 분포', alpha=0.5, rot=0)
# Out:
# <AxesSubplot:title={'center':'윤석열 주차별 레이블 분포'}>

# %%
# 전체 데이터 분포 확인
def posNneg(df):
    label = ['positive', 'negative']
    index =  np.arange(len(df['label']))
    value = [df['label'].value_counts()[1], df['label'].value_counts()[0]]
    plt.bar(label, value, color=['r', 'b'], alpha=0.5)
    plt.title('윤석열 - Distribution of Pos and Neg', fontsize=15)
    plt.xlabel('label')
    plt.ylabel('count')
    plt.show()
posNneg(df)

# %% [markdown]
# ### 전처리 코드

# %%
# Preprocessing code with Mecab
#dicpath="/usr/local/lib/mecab/dic/mecab-ko-dic"
mecab = Mecab(r"C:/mecab/mecab-ko-dic") # Mecab User Dic Path

def preprocessing_mecab(readData):
    
    #### Clean text
    #sentence = CleanText(readData)
    
    #### Tokenize
    morphs = mecab.pos(readData)
    
    JOSA = ["JKS", "JKC", "JKG", "JKO", "JKB", "JKV", "JKQ", "JX", "JC"] # 조사
    SIGN = ["SF", "SE", "SSO", "SSC", "SC", "SY"] # 문장 부호
    TERMINATION = ["EP", "EF", "EC", "ETN", "ETM"] # 어미
    SUPPORT_VERB = ["VX"] # 보조 용언
    NUMBER = ["SN"]
    
    # Remove JOSA, EOMI, etc
    morphs[:] = (morph for morph in morphs if morph[1] not in JOSA+SIGN+TERMINATION+SUPPORT_VERB)
        
    # Remove length-1 words  
    morphs[:] = (morph for morph in morphs if not (len(morph[0]) == 1))
    
    # Remove Numbers
    morphs[:] = (morph for morph in morphs if morph[1] not in NUMBER)
   
    # Result pop-up
    result = []
    for morph in morphs:
        result.append(morph[0])
        
    return result

# %% [markdown]
# ### 전체 텍스트 단어 빈도수 및 워드클라우드 생성

# %%
text = [' '.join(preprocessing_mecab(t)) for t in df['text']]
m_tokenized = df['text'].apply(lambda x: preprocessing_mecab(x))

# %%
# 불용어 리스트 생성
stop_words = pd.read_csv('./한국어불용어100.txt', sep = "\t", engine='python')
stop_words = list(stop_words["word"])

# %%
# 리스트 외에 의미없다고 판단되는 단어 리스트, 윤석열은 키워드이기 때문에 제외
stopwords = ['윤석열', '한다', '세요', '합니다', '입니다', 'ㅋㅋㅋ', 'ㅋㅋ','진짜', '아니', '근데', '그냥', '라고', '한다고', '해서', '이런', '어차피', '버리', '된다는','생겼', '인데', '해도', '된다', '이거', ]
stopwords = stopwords+stop_words

# %%
# 단어 빈도수 그래프 만들기
def word_frequency(m_tokenized):
    n_corpus = [] 
    for t in m_tokenized:
        for j in t:
            if j not in stopwords:
                n_corpus.append(j) #mecab에서 명사 추출

    count = collections.Counter(n_corpus) 
    most = count.most_common() #빈도 수 순으로 추출 
    x, y= [], [] 
    for word,count in most[:40]: 
        x.append(word) 
        y.append(count)
    #plt.rc('font',family='NanumGothic.ttf')
    plt.rcParams['font.family'] = "NanumGothic"
    plt.rcParams['axes.unicode_minus'] = False
    plt.figure(figsize=(10,10)) 
    sns.barplot(x=y,y=x)

# %%
# 전체 텍스트 단어 빈도수
word_frequency(m_tokenized)

# %%
def make_wordcloud(text):
    font_path = 'C:/Users/Erin/AppData/Local/Microsoft/Windows/Fonts/NanumGothic.ttf'
    wordcloud = WordCloud(font_path=font_path,
                background_color="black",
                stopwords=stopwords, 
                max_words=100, 
                #max_font_size=50, 
                width=500,
                height=500,
                random_state=1,
                scale=2).generate(''.join(text))
    fig = plt.figure(1, figsize=(8,8)) 
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('on')
    plt.show()

# %%
# 전체 텍스트
make_wordcloud(text)

# %% [markdown]
# ### 주차별 단어 빈도수 & 워드 클라우드 생성

# %%
# 단어 빈도수용 전처리된 string 요소 리스트 만들기
df1_text = [' '.join(preprocessing_mecab(t)) for t in df1['text']]
df2_text = [' '.join(preprocessing_mecab(t)) for t in df2['text']]
df3_text = [' '.join(preprocessing_mecab(t)) for t in df3['text']]
df4_text = [' '.join(preprocessing_mecab(t)) for t in df4['text']]

# %%
# 워드 클라우드용 전처리 및 토큰화된 리스트 만들기
df1_tokenized1 = df1['text'].apply(lambda x: preprocessing_mecab(x))
df2_tokenized2 = df2['text'].apply(lambda x: preprocessing_mecab(x))
df3_tokenized3 = df3['text'].apply(lambda x: preprocessing_mecab(x))
df3_tokenized4 = df4['text'].apply(lambda x: preprocessing_mecab(x))

# %%
dfs_text = [df1_text,df2_text,df3_text, df4_text]
dfs_tokenized = [df1_tokenized1, df2_tokenized2, df3_tokenized3, df3_tokenized4]

# %%
# 주차별 단어 빈도수 생성
for i in dfs_tokenized:
    word_frequency(i)

# %%
# 주차별 워드 클라우드 생성
for i in dfs_text:
    make_wordcloud(i)

# %% [markdown]
# ### 날짜별 최다 빈도 단어 추출

# %%
stopwords2 = ['뉴스', '출처', '국민','대통령','후보','이재명', '윤석열', '한다', '세요', '합니다', '입니다', 'ㅋㅋㅋ', 'ㅋㅋ','진짜', '아니', '근데', '그냥', '라고', '한다고', '해서', '이런', '어차피', '버리', '된다는','생겼', '인데', '해도', '된다', '이거', ]
stopwords = stopwords+stopwords2

# %%
df['tokenized'] = df['text'].apply(lambda x: preprocessing_mecab(x))
df['tokenized'] = df['tokenized'].apply(lambda x: [item for item in x if item not in stopwords])

# %%
def common_words(words, k):
    c = Counter(words)
    cw = c.most_common(k)
    return c, cw

def add_value_labels(ax, df, spacing=5):
    for idx, rect in enumerate(ax.patches):
        y_value = rect.get_height()
        x_value = rect.get_x() + rect.get_width() / 2
        space = spacing
        va = 'bottom'
        if y_value < 0:
            space *= -1
            va = 'top'

        label = "{0}".format(df['word'][idx])

        ax.annotate(
            label,                      # Use `label` as label
            (x_value, y_value),         # Place label at end of the bar
            xytext=(0, space),          # Vertically shift label by `space`
            textcoords="offset points", # Interpret `xytext` as offset in points
            ha='center',                # Horizontally center label
            va=va)

# 날짜별 가장 많이 언급된 단어와 단어의 갯수를 dict형태로 가져와서 dataframe으로 만들어주는 과정
date = []
word_list = []
count_list = []

for i in df['Datetime'].unique():
    tokenizing = sum(df[df['Datetime'] == i]['tokenized'],[])
    c, cw = common_words(tokenizing, 1)    
    word = cw[0][0]
    count = cw[0][1]
    date.append(i)
    word_list.append(word)
    count_list.append(count)
    
dateworddict = {'date' : date, 'word' : word_list, 'count' : count_list}
daily_df = pd.DataFrame(dateworddict, columns=['date', 'word', 'count'])

# graph
fig, ax = plt.subplots(1, figsize=(20,10))
plot = sns.barplot(daily_df['date'], daily_df['count'])
add_value_labels(ax, daily_df)
plot.set_xticklabels(plot.get_xticklabels(), rotation=45, horizontalalignment='right')
plt.title('most common word by date', fontsize=20)
plt.legend(fontsize=15)
#plt.save_fig("most common word by date")
# Out:
# c:\Users\Erin\anaconda3\envs\torch1\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### 해시태그 추출하기

# %%
# 정규표현식으로 #과 함께 있는 단어 추출 및 리스트 생성
import re
p = re.compile('[#]+[0-9a-zA-Z_ㄱ-ㅎ가-힣]+')
hash = []
for i in df['text']:
    hash.extend(p.findall(i))

# %%
# 해시태그 빈도수 확인
from collections import Counter
Counter(hash).most_common()
# Out:
# [('#윤석열', 1045),
#  ('#이재명', 315),
#  ('#shorts', 148),
#  ('#나를위해이재명', 102),
#  ('#대선', 98),
#  ('#국민의힘', 98),
#  ('#이재명은합니다', 95),
#  ('#앞으로', 90),
#  ('#제대로', 90),
#  ('#안철수', 89),
#  ('#김건희', 69),
#  ('#뉴데일리', 64),
#  ('#2번엔', 61),
#  ('#Shorts', 52),
#  ('#정권교체', 41),
#  ('#검찰개혁', 39),
#  ('#대장동', 38),
#  ('#김만배', 36),
#  ('#언론개혁', 35),
#  ('#사법개혁', 33),
#  ('#본부장비리', 33),
#  ('#뉴스', 28),
#  ('#최신뉴스', 27),
#  ('#신천지', 24),
#  ('#사전투표', 24),
#  ('#이준석', 23),
#  ('#TV토론', 20),
#  ('#단일화', 20),
#  ('#대통령선거', 20),
#  ('#박영수', 18),
#  ('#심상정', 18),
#  ('#SBS뉴스', 16),
#  ('#2', 16),
#  ('#검찰', 14),
#  ('#윤석열후보', 14),
#  ('#한동훈', 14),
#  ('#TikTok', 14),
#  ('#도이치모터스', 14),
#  ('#여론조사', 14),
#  ('#아이엠피터뉴스', 13),
#  ('#민주당', 13),
#  ('#착한투표', 13),
#  ('#검찰제국OUT', 13),
#  ('#윤석열은', 12),
#  ('#김학의무죄장모무죄', 12),
#  ('#문재인', 12),
#  ('#팩트체크', 12),
#  ('#이재명대통령', 12),
#  ('#더불어민주당', 11),
#  ('#윤석열처벌', 11),
#  ('#선라이즈는누구겁니까', 11),
#  ('#Tistory', 11),
#  ('#삼부토건', 11),
#  ('#1', 11),
#  ('#공멸', 10),
#  ('#윤석열찍고', 10),
#  ('#퇴마대선', 10),
#  ('#나를위해', 10),
#  ('#부산저축은행', 10),
#  ('#친일', 10),
#  ('#대선토론', 9),
#  ('#대선후보', 9),
#  ('#최은순', 9),
#  ('#건진법사', 9),
#  ('#노무현', 9),
#  ('#조남욱', 9),
#  ('#검언유착', 9),
#  ('#좌우통합레이드', 9),
#  ('#악귀퇴치', 9),
#  ('#주가조작', 9),
#  ('#1번이재명', 9),
#  ('#대장동의혹', 9),
#  ('#친일파', 9),
#  ('#윤석열게이트', 9),
#  ('#무당', 8),
#  ('#쥴리', 8),
#  ('#윤석열대통령', 8),
#  ('#오연호', 8),
#  ('#대통령', 8),
#  ('#멸공', 8),
#  ('#박근혜', 8),
#  ('#shindanmaker', 8),
#  ('#3', 7),
#  ('#채널A', 7),
#  ('#진영과', 7),
#  ('#20대대선', 7),
#  ('#유능한', 7),
#  ('#MediaVOP', 7),
#  ('#국민의당', 7),
#  ('#뉴스타파', 7),
#  ('#PEACE', 7),
#  ('#통일', 7),
#  ('#투표', 7),
#  ('#화천대유', 6),
#  ('#토론', 6),
#  ('#부동시', 6),
#  ('#우리가', 6),
#  ('#내표는여리꺼', 6),
#  ('#노동당', 6),
#  ('#보수', 6),
#  ('#블랙리스트', 6),
#  ('#안상수', 6),
#  ('#정치교체', 6),
#  ('#기호2번', 6),
#  ('#조시연', 6),
#  ('#우크라이나', 6),
#  ('#조우형', 6),
#  ('#임은정', 5),
#  ('#조남관', 5),
#  ('#공수처', 5),
#  ('#홍준표', 5),
#  ('#김종인', 5),
#  ('#2022대선', 5),
#  ('#다음뉴스', 5),
#  ('#FactCheck', 5),
#  ('#광주', 5),
#  ('#거짓말', 5),
#  ('#노영민', 5),
#  ('#검찰공화국', 5),
#  ('#여리', 5),
#  ('#족발열차', 5),
#  ('#이대남', 5),
#  ('#정치합시', 5),
#  ('#유세', 5),
#  ('#송영길', 5),
#  ('#위기의민주주의', 5),
#  ('#지지유세', 5),
#  ('#대선후보TV토론', 5),
#  ('#이재명은', 5),
#  ('#2번엔2번', 5),
#  ('#DPRK', 5),
#  ('#친일청산은', 5),
#  ('#검찰쿠테타는', 5),
#  ('#전쟁광', 5),
#  ('#평화', 5),
#  ('#지지연설', 5),
#  ('#여성이', 5),
#  ('#삼일절', 5),
#  ('#투표로', 5),
#  ('#김만배음성파일', 5),
#  ('#전두환', 4),
#  ('#하루백번복붙', 4),
#  ('#윤석열이', 4),
#  ('#검찰개혁촛불집회', 4),
#  ('#서초동집회', 4),
#  ('#광화문집회', 4),
#  ('#쥴리의사생활', 4),
#  ('#공적검증의대상', 4),
#  ('#열린공감TV', 4),
#  ('#추미애', 4),
#  ('#윤석열을수사하라', 4),
#  ('#국민의힘은', 4),
#  ('#대통령후보', 4),
#  ('#쩍벌남', 4),
#  ('#깐부', 4),
#  ('#딴지', 4),
#  ('#최강욱', 4),
#  ('#권성동', 4),
#  ('#장제원', 4),
#  ('#김건희구속', 4),
#  ('#SHORTS', 4),
#  ('#구둣발', 4),
#  ('#윤석열먹방', 4),
#  ('#야권단일화', 4),
#  ('#황교안', 4),
#  ('#방사능', 4),
#  ('#2번에는', 4),
#  ('#페미니즘', 4),
#  ('#내로남불', 4),
#  ('#6회', 4),
#  ('#가평5일장', 4),
#  ('#김만배녹취록', 4),
#  ('#종부세', 4),
#  ('#파주운정지구개발사업', 4),
#  ('#북한', 4),
#  ('#러시아', 4),
#  ('#설악5일장', 4),
#  ('#유시민', 4),
#  ('#대한독립만세', 4),
#  ('#이영', 4),
#  ('#채팅방', 4),
#  ('#윤석열OUT', 4),
#  ('#이명박정권', 4),
#  ('#최저임금', 4),
#  ('#정치보복', 3),
#  ('#이재명을', 3),
#  ('#나라위해이재명', 3),
#  ('#이낙연', 3),
#  ('#정책', 3),
#  ('#이런자를', 3),
#  ('#윤석열의범죄와연루', 3),
#  ('#주식', 3),
#  ('#정권교체에', 3),
#  ('#새날', 3),
#  ('#598부산행', 3),
#  ('#트렌드', 3),
#  ('#4자토론', 3),
#  ('#서울의소리', 3),
#  ('#윤핵관', 3),
#  ('#쇼츠', 3),
#  ('#김혜경', 3),
#  ('#안치환', 3),
#  ('#배은망덕한', 3),
#  ('#달빛잔향', 3),
#  ('#김의겸', 3),
#  ('#윤석열대통령후보', 3),
#  ('#젠더', 3),
#  ('#여성문제', 3),
#  ('#성평등', 3),
#  ('#석타필드', 3),
#  ('#곽상도', 3),
#  ('#뉴있저', 3),
#  ('#전국지표조사', 3),
#  ('#섹트', 3),
#  ('#위기에', 3),
#  ('#양희원', 3),
#  ('#사무금융노조', 3),
#  ('#더부천', 3),
#  ('#thebucheon', 3),
#  ('#지지율', 3),
#  ('#나를', 3),
#  ('#신현배', 3),
#  ('#이재명게이트', 3),
#  ('#재명이네', 3),
#  ('#김병민', 3),
#  ('#전주혜', 3),
#  ('#돌대가리', 3),
#  ('#윤석열사퇴', 3),
#  ('#촛불', 3),
#  ('#황하영', 3),
#  ('#검찰독재', 3),
#  ('#대장동개발사업', 3),
#  ('#화이팅', 3),
#  ('#이태규', 3),
#  ('#도이치모터스주가조작의혹', 3),
#  ('#닥터김', 3),
#  ('#northkorea', 3),
#  ('#사자토론', 3),
#  ('#국민의짐', 3),
#  ('#매국노', 3),
#  ('#자위대', 3),
#  ('#Vote', 3),
#  ('#국민의', 3),
#  ('#황현필', 3),
#  ('#국힘당', 3),
#  ('#삿대질', 3),
#  ('#성접대', 3),
#  ('#노조', 3),
#  ('#신학림', 3),
#  ('#서울시청광장', 3),
#  ('#비리종합세트', 2),
#  ('#무능', 2),
#  ('#윤틀러', 2),
#  ('#국민', 2),
#  ('#우리가언론', 2),
#  ('#이재명펀드깡', 2),
#  ('#이재명펀드', 2),
#  ('#윤석열을지지한다', 2),
#  ('#토리아빠윤석열', 2),
#  ('#제보자a씨신변보호', 2),
#  ('#독립운동가', 2),
#  ('#Facebook', 2),
#  ('#이재명후보', 2),
#  ('#양도소득세', 2),
#  ('#양도세', 2),
#  ('#증권거래세', 2),
#  ('#해동인간', 2),
#  ('#윤석열검찰공화국OUT', 2),
#  ('#냉동인간', 2),
#  ('#이재명지지', 2),
#  ('#선제타격', 2),
#  ('#공정', 2),
#  ('#상식', 2),
#  ('#59초공약짤', 2),
#  ('#저40퍼', 2),
#  ('#김건희녹취록', 2),
#  ('#부정선거감시', 2),
#  ('#기독교', 2),
#  ('#고소', 2),
#  ('#이만희', 2),
#  ('#장모', 2),
#  ('#김은혜', 2),
#  ('#우리가언론이다', 2),
#  ('#김누리', 2),
#  ('#구속', 2),
#  ('#뉴', 2),
#  ('#뉴데', 2),
#  ('#토리아빠', 2),
#  ('#군면제', 2),
#  ('#고교', 2),
#  ('#이재명극혐', 2),
#  ('#망언', 2),
#  ('#윤석열토론', 2),
#  ('#언론', 2),
#  ('#무당힘', 2),
#  ('#신천지힘', 2),
#  ('#쥴리는누구입니까', 2),
#  ('#쥬얼리', 2),
#  ('#김명신', 2),
#  ('#적폐척결', 2),
#  ('#딴지만평', 2),
#  ('#부정선거', 2),
#  ('#무속', 2),
#  ('#무속논란', 2),
#  ('#부산', 2),
#  ('#사이비종교', 2),
#  ('#독재', 2),
#  ('#탈핵', 2),
#  ('#MToday', 2),
#  ('#서울', 2),
#  ('#57', 2),
#  ('#유승민', 2),
#  ('#무속열', 2),
#  ('#연예', 2),
#  ('#김장환', 2),
#  ('#윤석열이만희', 2),
#  ('#ㅅㅊㅈ', 2),
#  ('#집사부일체', 2),
#  ('#경기일보', 2),
#  ('#애국보수', 2),
#  ('#노무현한테', 2),
#  ('#비서관', 2),
#  ('#우상호', 2),
#  ('#사드', 2),
#  ('#동아일보', 2),
#  ('#똥파리', 2),
#  ('#YTN', 2),
#  ('#45년구형', 2),
#  ('#동물을위한투표', 2),
#  ('#시그널', 2),
#  ('#부동산', 2),
#  ('#검찰공화국반대', 2),
#  ('#참여연대', 2),
#  ('#윤여준', 2),
#  ('#인천', 2),
#  ('#서구갑', 2),
#  ('#이학재가함께합니다', 2),
#  ('#윤석열은희망등대', 2),
#  ('#자유대한민국', 2),
#  ('#선거개입', 2),
#  ('#도이치모터스주가조작', 2),
#  ('#사노맹조국', 2),
#  ('#문재인정부', 2),
#  ('#김평우', 2),
#  ('#홍문종의', 2),
#  ('#윤희숙', 2),
#  ('#2번엔윤석열', 2),
#  ('#추경', 2),
#  ('#이명박', 2),
#  ('#진영과지역을넘어', 2),
#  ('#국민통합', 2),
#  ('#이재명지지선언', 2),
#  ('#이양호', 2),
#  ('#위기에강한', 2),
#  ('#윤석열지지', 2),
#  ('#윤석열찍으면이재명감옥간다', 2),
#  ('#49회', 2),
#  ('#경제대통령', 2),
#  ('#김대중', 2),
#  ('#윤석열은사퇴하라', 2),
#  ('#2022년', 2),
#  ('#정치', 2),
#  ('#다음', 2),
#  ('#무식무지무능', 2),
#  ('#입만열면거짓말', 2),
#  ('#지지도', 2),
#  ('#후보', 2),
#  ('#이회창', 2),
#  ('#병역면제', 2),
#  ('#청와대', 2),
#  ('#윤영찬', 2),
#  ('#김어준', 2),
#  ('#윤석렬', 2),
#  ('#도이치모터스주가조작사건', 2),
#  ('#대선TV토론', 2),
#  ('#대장동그분', 2),
#  ('#범인', 2),
#  ('#대한민국을위해이재명', 2),
#  ('#유능한경제대통령', 2),
#  ('#윤석열부친', 2),
#  ('#백낙처', 2),
#  ('#고민정', 2),
#  ('#청평5일장', 2),
#  ('#39', 2),
#  ('#민주팔이단', 2),
#  ('#멸공다방', 2),
#  ('#노노재팬', 2),
#  ('#스타Bugs', 2),
#  ('#검찰쿠테타', 2),
#  ('#수구지지', 2),
#  ('#법조카르텔척결', 2),
#  ('#언론카르텔척결', 2),
#  ('#백두산', 2),
#  ('#한라산', 2),
#  ('#검찰총장', 2),
#  ('#수원', 2),
#  ('#트럼프', 2),
#  ('#후보사퇴', 2),
#  ('#젤렌스키', 2),
#  ('#2번선거는', 2),
#  ('#소신투표', 2),
#  ('#대선후보자토론', 2),
#  ('#지지선언', 2),
#  ('#KOREA', 2),
#  ('#불평등', 2),
#  ('#능력주의', 2),
#  ('#장시간노동', 2),
#  ('#산재', 2),
#  ('#기업살인', 2),
#  ('#야수자본주의', 2),
#  ('#대장동게이트', 2),
#  ('#국힘', 2),
#  ('#푸틴', 2),
#  ('#위키트리', 2),
#  ('#그래도', 2),
#  ('#대세는', 2),
#  ('#국짐당', 2),
#  ('#태도가', 2),
#  ('#여명', 2),
#  ('#전쟁', 2),
#  ('#다스뵈이다', 2),
#  ('#장제원의원', 2),
#  ('#No', 2),
#  ('#김부선', 2),
#  ('#제주도', 2),
#  ('#통합정부', 2),
#  ('#SNS', 2),
#  ('#어게인', 2),
#  ('#한국갤럽', 2),
#  ('#여론조사지지율', 2),
#  ('#안철수단일화', 2),
#  ('#특검', 2),
#  ('#세종시', 2),
#  ('#행정수도', 2),
#  ('#이상돈', 2),
#  ('#51회', 2),
#  ('#군대가라고하니짝눈이고공무원시험볼때는정상', 2),
#  ('#늘어나라고무고무시력ㅋㅋㅋ', 2),
#  ('#인생이거짓말', 2),
#  ('#병역비리', 2),
#  ('#20번방', 2),
#  ('#특전사', 2),
#  ('#황운하', 2),
#  ('#검경수사권분리', 2),
#  ('#기획수사', 2),
#  ('#기호1번', 2),
#  ('#대장동특검', 2),
#  ('#조건만남', 2),
#  ('#이재명미담', 2),
#  ('#밭갈이', 2),
#  ('#실패', 2),
#  ('#20대', 2),
#  ('#토리', 2),
#  ('#허위경력', 2),
#  ('#윤석열은응답하라', 2),
#  ('#녹취록', 2),
#  ('#음성파일', 2),
#  ('#이재명을청와대로', 2),
#  ('#삼성전자', 2),
#  ('#권영세', 2),
#  ('#빼박증거', 2),
#  ('#강남역', 2),
#  ('#윤석열장모', 2),
#  ('#무식', 1),
#  ('#윤찍김', 1),
#  ('#김건희윤석열건진법사연관', 1),
#  ('#김건희도이치모터스주가조작', 1),
#  ('#홍진경찐천재', 1),
#  ('#허위임명장', 1),
#  ('#윤무식', 1),
#  ('#도사', 1),
#  ('#부산저축은행부실수사', 1),
#  ('#검사마인드', 1),
#  ('#왜곡된검찰관', 1),
#  ('#태극기', 1),
#  ('#극문오소리', 1),
#  ('#매세지220210', 1),
#  ('#내부에', 1),
#  ('#시사의품격', 1),
#  ('#사모펀드', 1),
#  ('#룸싸롱', 1),
#  ('#김주완', 1),
#  ('#강창덕', 1),
#  ('#김종길', 1),
#  ('#뉴스공장', 1),
#  ('#나의촛불', 1),
#  ('#잘못한게없으면뭐가두렵나', 1),
#  ('#윤석열개검', 1),
#  ('#낙선', 1),
#  ('#윤석열도', 1),
#  ('#막장검찰', 1),
#  ('#꽃뱀사기단', 1),
#  ('#정치보복선언', 1),
#  ('#굿힘의여론공작단교육', 1),
#  ('#윤미향', 1),
#  ('#윤석열제거', 1),
#  ('#여가부', 1),
#  ('#문프', 1),
#  ('#리재명', 1),
#  ('#도리거니쌍것들쳐죽여꼭귀태청산하라', 1),
#  ('#더민주', 1),
#  ('#윤검특위', 1),
#  ('#이재명법카횡령', 1),
#  ('#이재명아들', 1),
#  ('#이재명수사촉구', 1),
#  ('#홍카콜라', 1),
#  ('#촛불사법처리', 1),
#  ('#반헌법적윤석열', 1),
#  ('#윤석열비리', 1),
#  ('#시민사회단체', 1),
#  ('#맞팔100', 1),
#  ('#맞팔', 1),
#  ('#대선여론조사', 1),
#  ('#리서치뷰', 1),
#  ('#제보자들', 1),
#  ('#사과해', 1),
#  ('#적폐수사', 1),
#  ('#법과', 1),
#  ('#적패1호는', 1),
#  ('#검수완박', 1),
#  ('#최재형', 1),
#  ('#안철수마이웨이', 1),
#  ('#노무현문재인', 1),
#  ('#아이엠피터', 1),
#  ('#틀튜브', 1),
#  ('#54', 1),
#  ('#특수활동비', 1),
#  ('#법무부', 1),
#  ('#70년대', 1),
#  ('#송작가TV', 1),
#  ('#윤석열특활비178억원', 1),
#  ('#박근혜지지자', 1),
#  ('#김건희를구속수사하라', 1),
#  ('#도이치모터스주가조작김건희', 1),
#  ('#도덕불감증', 1),
#  ('#윤리', 1),
#  ('#독불쌍놈', 1),
#  ('#자격미달', 1),
#  ('#윤석열사퇴하라', 1),
#  ('#홍영표', 1),
#  ('#EnoughIsEnough', 1),
#  ('#기억력조루증환자', 1),
#  ('#각오하시라', 1),
#  ('#시간조차도', 1),
#  ('#관심법', 1),
#  ('#진보당', 1),
#  ('#김재연', 1),
#  ('#토론장거짖해명', 1),
#  ('#입만열면거짖말윤석열', 1),
#  ('#김건희도이치모터스거래내역허위누락공개', 1),
#  ('#욕바라지먹기딱좋은놈', 1),
#  ('#윤석열적폐본인부인장모수사하지', 1),
#  ('#장면1', 1),
#  ('#우리가족은', 1),
#  ('#이재명토론회완승', 1),
#  ('#윤석열초보운전자위험해', 1),
#  ('#적폐윤석열', 1),
#  ('#윤석열거짓말', 1),
#  ('#친중숭북', 1),
#  ('#특활비', 1),
#  ('#토론고자', 1),
#  ('#토론배틀', 1),
#  ('#꼴페미', 1),
#  ('#고소고발', 1),
#  ('#JM', 1),
#  ('#유능진보', 1),
#  ('#김건희무당', 1),
#  ('#문석열', 1),
#  ('#문재인의충신윤석열', 1),
#  ('#앤비책장', 1),
#  ('#예스24', 1),
#  ('#베스트셀러순위', 1),
#  ('#유피체인', 1),
#  ('#upchain', 1),
#  ('#횡령궁', 1),
#  ('#횡령나비', 1),
#  ('#횡령부부단', 1),
#  ('#경기도법카횡령', 1),
#  ('#선관위감시', 1),
#  ('#공수처에', 1),
#  ('#부산LCT특검하라', 1),
#  ('#인터뷰', 1),
#  ('#아산신도시', 1),
#  ('#LH', 1),
#  ('#지지선언위조', 1),
#  ('#허위', 1),
#  ('#위조', 1),
#  ('#무속정치', 1),
#  ('#잡신민국', 1),
#  ('#찢사학자', 1),
#  ('#세금체납', 1),
#  ('#7만원', 1),
#  ('#방역법위반', 1),
#  ('#전과몇범', 1),
#  ('#보배드림', 1),
#  ('#계좌', 1),
#  ('#통장', 1),
#  ('#129억', 1),
#  ('#김만희', 1),
#  ('#배신자호로새퀴', 1),
#  ('#종교대통합', 1),
#  ('#필승', 1),
#  ('#굿당', 1),
#  ('#멸망', 1),
#  ('#윤석열돌대가리', 1),
#  ('#적폐당', 1),
#  ('#민폐당', 1),
#  ('#윤석열차', 1),
#  ('#멈춰', 1),
#  ('#환멸', 1),
#  ('#장자연', 1),
#  ('#조선일보', 1),
#  ('#방상훈', 1),
#  ('#대통령임기5년이뭐가대단하다고', 1),
#  ('#냉동깡통', 1),
#  ('#입안보', 1),
#  ('#토마호크', 1),
#  ('#명의도용', 1),
#  ('#미성숙', 1),
#  ('#불가능', 1),
#  ('#구두는', 1),
#  ('#보복정치', 1),
#  ('#경련', 1),
#  ('#무슨수를쓰던막아야되지않겠습니까', 1),
#  ('#윤석열특보', 1),
#  ('#먹는데진심', 1),
#  ('#스트리트푸드파이터', 1),
#  ('#면접', 1),
#  ('#배신', 1),
#  ('#투표용지인쇄일', 1),
#  ('#한국교육', 1),
#  ('#윤석열선재타격킬체인', 1),
#  ('#1982년', 1),
#  ('#신발', 1),
#  ('#공부왕', 1),
#  ('#수포자', 1),
#  ('#노동시장', 1),
#  ('#최승환교수', 1),
#  ('#자영업자들', 1),
#  ('#이재명을위하여', 1),
#  ('#구두', 1),
#  ('#윤석열만아니면됩니다', 1),
#  ('#양아치이재명당', 1),
#  ('#이재명부인', 1),
#  ('#이재명민주당', 1),
#  ('#손고모구국자봉단', 1),
#  ('#제20대대통령선거', 1),
#  ('#후보등록', 1),
#  ('#정치합시다', 1),
#  ('#윤씨발', 1),
#  ('#릴레이', 1),
#  ('#이재명을거부합니다', 1),
#  ('#SARCASM', 1),
#  ('#윤석열하이라이트', 1),
#  ('#무정도사', 1),
#  ('#이만희총회장', 1),
#  ('#우리가남이가', 1),
#  ('#검수완박이', 1),
#  ('#퇴직금', 1),
#  ('#오천만원', 1),
#  ('#김웅', 1),
#  ('#안철수공약정리', 1),
#  ('#법사의힘', 1),
#  ('#윤사마', 1),
#  ('#군화발', 1),
#  ('#검사세상', 1),
#  ('#개작두', 1),
#  ('#쥴리는누구겁니꽈', 1),
#  ('#적폐검사', 1),
#  ('#검더기척결', 1),
#  ('#전태일을', 1),
#  ('#이재명당', 1),
#  ('#죽은', 1),
#  ('#인성', 1),
#  ('#비매너', 1),
#  ('#이완배', 1),
#  ('#흰눈', 1),
#  ('#배은망덕', 1),
#  ('#문파는반문이재명안찍어요', 1),
#  ('#윤석열구둣발', 1),
#  ('#특권의식', 1),
#  ('#유튜브', 1),
#  ('#퇴줄', 1),
#  ('#두목', 1),
#  ('#부도덕', 1),
#  ('#사전선거', 1),
#  ('#권영세헛소리', 1),
#  ('#허위사실유포로', 1),
#  ('#씨발단', 1),
#  ('#알콜성치매윤석열', 1),
#  ('#세가지', 1),
#  ('#계급의식', 1),
#  ('#전략공천', 1),
#  ('#부메랑', 1),
#  ('#자충수', 1),
#  ('#주술', 1),
#  ('#사이비종교처럼', 1),
#  ('#술꾼', 1),
#  ('#대형교회', 1),
#  ('#목사님들', 1),
#  ('#뉴데일', 1),
#  ('#김장환목사', 1),
#  ('#극우', 1),
#  ('#기후', 1),
#  ('#기후공약', 1),
#  ('#주요후보', 1),
#  ('#탈석탄', 1),
#  ('#재생에너지', 1),
#  ('#지구해요', 1),
#  ('#뉴스펭귄', 1),
#  ('#떼창', 1),
#  ('#대선토론하이라이트', 1),
#  ('#CNN', 1),
#  ('#대통령선거유세', 1),
#  ('#테스형', 1),
#  ('#개같은깐부', 1),
#  ('#뇌물', 1),
#  ('#대구', 1),
#  ('#이재명이바꿉니다', 1),
#  ('#신곡', 1),
#  ('#논란', 1),
#  ('#대통령호소인', 1),
#  ('#기호4번', 1),
#  ('#안철수대통령', 1),
#  ('#국짐당과신천지', 1),
#  ('#동물학대반대', 1),
#  ('#나홀로운동장', 1),
#  ('#파란운동화', 1),
#  ('#하지마', 1),
#  ('#내표윤표', 1),
#  ('#제20대', 1),
#  ('#국민이키우고', 1),
#  ('#국민이만들', 1),
#  ('#장풍', 1),
#  ('#윤석열장풍', 1),
#  ('#가자대한민국', 1),
#  ('#대한민국대통령', 1),
#  ('#소신발언', 1),
#  ('#아무리그래도그렇지윤석열은아니자너', 1),
#  ('#죄인곽상도', 1),
#  ('#윤석열김치찌개', 1),
#  ('#파란옷', 1),
#  ('#건희로드맵이나짜라', 1),
#  ('#주제파악이안되나', 1),
#  ('#윤쫄보', 1),
#  ('#마스크', 1),
#  ('#삼미시장', 1),
#  ('#경기포토', 1),
#  ('#이재명마스크', 1),
#  ('#이재명팩트체크', 1),
#  ('#대장동특혜조사위원회설치', 1),
#  ('#세월호', 1),
#  ('#반일', 1),
#  ('#거짓', 1),
#  ('#전통시장', 1),
#  ('#쇼핑몰', 1),
#  ('#채널a기자카톡', 1),
#  ('#민주당폭망', 1),
#  ('#대선유세', 1),
#  ('#적폐수사론', 1),
#  ('#지역주의', 1),
#  ('#횡령초밥이더맛있다', 1),
#  ('#나쁜투표', 1),
#  ('#종노근성', 1),
#  ('#최악의', 1),
#  ('#천인공로할', 1),
#  ('#유세버스', 1),
#  ('#미중', 1),
#  ('#짜도짜도썩은물', 1),
#  ('#좌우통합퍼레이드', 1),
#  ('#적폐덩어리', 1),
#  ('#이동재와동료기자', 1),
#  ('#수꼴보수들', 1),
#  ('#불법촬영', 1),
#  ('#sns', 1),
#  ('#도깨비', 1),
#  ('#대한민국을위해', 1),
#  ('#조원진', 1),
#  ('#레알가능', 1),
#  ('#믿을까', 1),
#  ('#여성가족부폐지', 1),
#  ('#유세차', 1),
#  ('#파란불이재명은법규준수', 1),
#  ('#30회', 1),
#  ('#사기', 1),
#  ('#차명소유', 1),
#  ('#세금탈루', 1),
#  ('#정치보복연설', 1),
#  ('#낳는다', 1),
#  ('#강남', 1),
#  ('#씨발', 1),
#  ('#투머치토커', 1),
#  ('#김의겸tv', 1),
#  ('#방역수칙', 1),
#  ('#이원집정제로가는윤석열가짜보수들', 1),
#  ('#사전투표권유하는사긱꾼국민벅수똥당', 1),
#  ('#형수쌍욕공개하자', 1),
#  ('#NewsBreak', 1),
#  ('#성남', 1),
#  ('#윤두환', 1),
#  ('#돈많은북한된다', 1),
#  ('#최민희', 1),
#  ('#조은희', 1),
#  ('#내로남불의', 1),
#  ('#조국', 1),
#  ('#신간도서', 1),
#  ('#답변거부', 1),
#  ('#정책질의', 1),
#  ('#부산저축은행수많은피해자들의피땀눈물목숨으로살면좋은거니', 1),
#  ('#검찰선거개입', 1),
#  ('#김건희주가조작', 1),
#  ('#구미', 1),
#  ('#이재명이싫어요', 1),
#  ('#2번엔윤석', 1),
#  ('#한겨레', 1),
#  ('#누가윤석열쩍벌도리개족을키운거니', 1),
#  ('#오또케', 1),
#  ('#뉴스정면승부', 1),
#  ('#부패하고', 1),
#  ('#지나간', 1),
#  ('#주호영', 1),
#  ('#줄리', 1),
#  ('#비공개', 1),
#  ('#더레프트', 1),
#  ('#원명스님', 1),
#  ('#민주당지지철회', 1),
#  ('#굿바이', 1),
#  ('#추경반대', 1),
#  ('#오미크론', 1),
#  ('#소상공인', 1),
#  ('#자영업자', 1),
#  ('#삭발', 1),
#  ('#민생회복', 1),
#  ('#당선즉시보상', 1),
#  ('#정치합시다2', 1),
#  ('#행동하는', 1),
#  ('#입', 1),
#  ('#생생한', 1),
#  ('#이재명찍고', 1),
#  ('#민비', 1),
#  ('#민영환', 1),
#  ('#원균', 1),
#  ('#6를시작해', 1),
#  ('#저격논란', 1),
#  ('#껍데기는가라', 1),
#  ('#큰성취감', 1),
#  ('#정규제', 1),
#  ('#양심선언', 1),
#  ('#각성', 1),
#  ('#저지', 1),
#  ('#경악중', 1),
#  ('#2번에', 1),
#  ('#이번에도', 1),
#  ('#국격', 1),
#  ('#김미경', 1),
#  ('#압도적승리', 1),
#  ('#안진걸TV', 1),
#  ('#조재연', 1),
#  ('#국민의머슴', 1),
#  ('#선거운동의', 1),
#  ('#동행', 1),
#  ('#촛불항쟁', 1),
#  ('#사절합니다', 1),
#  ('#박범계', 1),
#  ('#토론하이라이트', 1),
#  ('#울산', 1),
#  ('#4636', 1),
#  ('#2리와서', 1),
#  ('#김동연', 1),
#  ('#내비둬라', 1),
#  ('#제3지대', 1),
#  ('#새로운물결', 1),
#  ('#새물결', 1),
#  ('#기호9번', 1),
#  ('#구원투수', 1),
#  ('#포털', 1),
#  ('#위험한윤석열', 1),
#  ('#조작의힘', 1),
#  ('#굿당의힘', 1),
#  ('#검찰당', 1),
#  ('#선동질', 1),
#  ('#절대방심금물', 1),
#  ('#43', 1),
#  ('#42', 1),
#  ('#언론에서사라짐', 1),
#  ('#리얼미터', 1),
#  ('#육군', 1),
#  ('#공군', 1),
#  ('#해군', 1),
#  ('#이코노미스트', 1),
#  ('#세계대전망', 1),
#  ('#반기문', 1),
#  ('#GOOD재명', 1),
#  ('#굿석열', 1),
#  ('#유엔사', 1),
#  ('#초딩징징', 1),
#  ('#김인천', 1),
#  ('#신동훈', 1),
#  ('#청평주민', 1),
#  ('#국민과', 1),
#  ('#완주', 1),
#  ('#김만배의뒷배는', 1),
#  ('#만능짤', 1),
#  ('#파괴공약', 1),
#  ('#윤석열팔뚝질욕', 1),
#  ('#윤석열어퍼컷', 1),
#  ('#2022통합의', 1),
#  ('#대통령윤석열', 1),
#  ('#김건희녹취', 1),
#  ('#9gag', 1),
#  ('#거짓말이', 1),
#  ('#잔인하다잔인해', 1),
#  ('#카드', 1),
#  ('#법인카드횡령', 1),
#  ('#보면', 1),
#  ('#경제폭망윤석열', 1),
#  ('#역사의죄인', 1),
#  ('#IMF온다', 1),
#  ('#아무리봐도', 1),
#  ('#전문가가', 1),
#  ('#이재명이답이다', 1),
#  ('#윤석열퇴출', 1),
#  ('#인간에', 1),
#  ('#홍준표를', 1),
#  ('#X별들', 1),
#  ('#무당아바타', 1),
#  ('#김만배측근윤석열', 1),
#  ('#이승만', 1),
#  ('#박정희', 1),
#  ('#국민이', 1),
#  ('#정영학회계사', 1),
#  ('#대장동자금책', 1),
#  ('#조우형대출브로커', 1),
#  ('#채배근', 1),
#  ('#알이백', 1),
#  ('#기축통화', 1),
#  ('#기축통화국', 1),
#  ('#안철수가윤석열을만나면절레절레', 1),
#  ('#윤석열은늘항상언제나도리도리', 1),
#  ('#대머리', 1),
#  ('#허위사실공표', 1),
#  ('#유세단', 1),
#  ('#설악장', 1),
#  ('#대토령선거', 1),
#  ('#이철휘위원장', 1),
#  ('#결단을', 1),
#  ('#석동현', 1),
#  ('#윤석열의보복정치', 1),
#  ('#20대대통령', 1),
#  ('#목격자', 1),
#  ('#증언', 1),
#  ('#유상범', 1),
#  ('#주식양도세', 1),
#  ('#관계', 1),
#  ('#연루', 1),
#  ('#위대한국민', 1),
#  ('#뜻', 1),
#  ('#이학재가간다', 1),
#  ('#따릉이자전거유세단', 1),
#  ('#정영학녹취록', 1),
#  ('#시장경제', 1),
#  ('#파괴', 1),
#  ('#대선후보법정토론회', 1),
#  ('#더불어민주당이재명', 1),
#  ('#국민의힘윤석열', 1),
#  ('#거짓말달인', 1),
#  ('#김범수', 1),
#  ('#카카오', 1),
#  ('#이재명선거유세', 1),
#  ('#이재명연설', 1),
#  ('#가족비리', 1),
#  ('#정경심교수유죄때린조재연', 1),
#  ('#최근지지율', 1),
#  ('#대선후보지지율', 1),
#  ('#지지율골든크로스', 1),
#  ('#나는고발한다', 1),
#  ('#홍서윤', 1),
#  ('#2번나비는행복', 1),
#  ('#전투왕', 1),
#  ('#민주당의', 1),
#  ('#오늘의', 1),
#  ('#클베충', 1),
#  ('#클리앙', 1),
#  ('#정희진', 1),
#  ('#정희진의낯선사이', 1),
#  ('#경향신문', 1),
#  ('#칼럼', 1),
#  ('#여성주의', 1),
#  ('#iShortener', 1),
#  ('#장애인', 1),
#  ('#윤석열장애인식', 1),
#  ('#정치적부채', 1),
#  ('#문제인2', 1),
#  ('#총명한아드님', 1),
#  ('#잘키운아버님', 1),
#  ('#합당', 1),
#  ('#고공', 1),
#  ('#번지점프', 1),
#  ('#김건희목덜미잡은놈수행원이아니라무속인', 1),
#  ('#김건희가캠프인사할때관상보는게필수ㅋ', 1),
#  ...]

# %%
def hashtag(wordInfo):
        Sorted_Dict_Values = sorted(wordInfo.values(), reverse=False)
        Sorted_Dict_Keys = sorted(wordInfo, key=wordInfo.get, reverse=False)
        plt.figure(figsize=(20, 10))
        plot = sns.barplot(Sorted_Dict_Keys, Sorted_Dict_Values)
        plot.set_xticklabels(plot.get_xticklabels(), rotation=45, horizontalalignment='right')
        plt.title('most common hashtag', fontsize=20)
        plt.legend(fontsize=15)

# %%
count = dict(Counter(hash).most_common(40))           
hashtag(count)
# Out:
# c:\Users\Erin\anaconda3\envs\torch1\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
