# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import matplotlib
import matplotlib_inline
import seaborn as sns
from wordcloud import WordCloud
import matplotlib.font_manager as fm
import collections

# %%
df = pd.read_csv('./CrawledData/소신투표/소신투표_unsmile.csv',encoding='utf-8')

# %%
label = ['여성/가족', '남성', '성소수자', '인종/국적', '연령', '지역', '종교', '기타 혐오', '악플/욕설', 'clean']

# %%
stats = []
for i in label:
    stats.append(df[i].sum())

# %%
plt.rcParams['font.family'] = "NanumGothic"
plt.rcParams['axes.unicode_minus'] = False

# %%
#wedgeprops={'width': 0.5, 'edgecolor': 'w', 'linewidth': 2}
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0', '#2962FF', '#00c853', '#f57f17', '#ffea00', '#1De9B6', '#b39ddb']
plt.axis=('equal')
plt.title('소신투표')
plt.pie(stats, labels=label, autopct='%.2f%%', colors=colors)
plt.show()

# %%
# 카테고리별로 점수가 높은 순서대로 정렬
df_woman = df.sort_values(by='여성/가족', ascending=False).groupby('text').head(10)
df_man = df.sort_values(by='남성', ascending=False).groupby('text').head(10)
df_region = df.sort_values(by='지역', ascending=False).groupby('text').head(10)
df_queer = df.sort_values(by='성소수자', ascending=False).groupby('text').head(10)
df_religion = df.sort_values(by='종교', ascending=False).groupby('text').head(10)

# %%
df_woman.head(20)
# Out:
#                                                    text  label  여성/가족    남성  \
# 1197  한녀들 소신투표한다고 자기 신념 버리고 울며 겨자먹기로 투표하는 여자들한테 묻어가는...      0   0.92  0.06
# 1146  심상정 안철수 소신투표 하신다는 한녀들은 이거 보고 가세요 ㅋㅋ 현실은 잔혹함 소신...      0   0.92  0.05
# 2432  방금 트렌드를 쭉 훑어 봤는데 꼴페미들은 여가부 폐지 윤석열대 이재명으로 소신투표V...      0   0.92  0.02
# 776   페미들아 소신투표 집어치우고 여성인권을 위해 찢재명 꼭 찍길 바란다 내연녀에 입에 ...      0   0.91  0.02
# 173                    여자들아 소신투표 이지랄하지말고 걍 이재명뽑아라 제발 제발      0   0.91  0.02
# 3234  이런데도 #소신투표 하겠다는 입페미들은 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 페미라고도 하지말아      0   0.90  0.02
# 1073  소신투표 좋지 근데 이때까지 여자들이 정의당뽑고 여성의당 뽑은걸 보답받았냐고 이번에...      0   0.90  0.07
# 908   지금 소신투표 운운하는 한녀들 이거같음 당장 다같이 반페미정부한테 5년동안 임신기계...      0   0.90  0.04
# 778   이번 대선에서 소신투표를 하지 말아야 할 이유는 소신투표를 할때는 결과가 어떻든 내...      0   0.90  0.03
# 2332           여자들 제발 소신투표 No 표 갈라지면 여자들의 인생이 좃될 수 있습니다      0   0.90  0.07
# 963            나도 소신투표 하려했는데 그냥 윤이 ㅋㅋ 여자는 개돼지 미만 취급하겠대서      0   0.89  0.03
# 1485  입페미들아 이게 바로 여성을 위한 정책이다 #소신투표 라고 하지말고 그냥 이재명 좋...      0   0.89  0.03
# 3320         여자들아 이재명 뽑자 소신투표도 ㅆㅂ 국회의원뽑을때나해야지 이건 대선임 ㅅㅂ      0   0.89  0.03
# 358   소신투표때문에 트럼프가 당선되었다는 건 인과관계가 전혀 안 맞는 소리지만 2020경...      0   0.89  0.02
# 3210                  여자들아 소신 투표 할 때가 아님 여권 20년 후퇴하게 생김      0   0.88  0.04
# 1123  페미년들 실트에 소신투표 ㅇㅈㄹ한거 왤케 웃기냐 ㅋㅋㅋㅋ 야 니네가 소신투표한다고 ...      0   0.88  0.02
# 2356  그러니까 니들한테 표 안 주면 소신투표가 아니란 거잖아요 여자 표 모으겠다면서 여자...      0   0.87  0.04
# 1107  윤석열 당선되면 앞으로 여자들은 페미니즘 이라는 말을 볼드모트마냥 입에 올리지도 못...      0   0.87  0.02
# 443   저 소신 투표 심 하려다가 맘 바꿔먹었잖아요 윤 되면 한녀들 단체로 망할거 뻔해서 ...      0   0.87  0.08
# 1945  여자들 지금 소신투표한다고 심상정 뽑을거다 ㅇ러고잇는데 진짜 이거 표갈라치기라고 나...      0   0.86  0.02
#
#       성소수자  인종/국적    연령    지역    종교  기타 혐오  악플/욕설  clean
# 1197  0.02   0.04  0.02  0.02  0.02   0.03   0.04   0.04
# 1146  0.02   0.04  0.02  0.02  0.02   0.04   0.04   0.05
# 2432  0.02   0.04  0.02  0.02  0.01   0.05   0.05   0.08
# 776   0.02   0.04  0.01  0.03  0.02   0.06   0.07   0.04
# 173   0.02   0.03  0.02  0.04  0.02   0.04   0.07   0.07
# 3234  0.02   0.03  0.02  0.02  0.01   0.05   0.07   0.05
# 1073  0.02   0.04  0.01  0.02  0.01   0.03   0.05   0.07
# 908   0.02   0.04  0.02  0.01  0.02   0.03   0.06   0.05
# 778   0.03   0.04  0.01  0.02  0.01   0.03   0.04   0.07
# 2332  0.02   0.02  0.02  0.02  0.01   0.03   0.05   0.06
# 963   0.01   0.03  0.02  0.03  0.01   0.03   0.07   0.07
# 1485  0.02   0.02  0.02  0.02  0.01   0.04   0.07   0.06
# 3320  0.01   0.03  0.02  0.03  0.01   0.05   0.13   0.05
# 358   0.01   0.04  0.02  0.02  0.02   0.04   0.11   0.08
# 3210  0.02   0.03  0.02  0.02  0.01   0.03   0.06   0.10
# 1123  0.02   0.03  0.01  0.02  0.01   0.03   0.10   0.07
# 2356  0.02   0.02  0.02  0.02  0.01   0.03   0.11   0.05
# 1107  0.02   0.02  0.01  0.02  0.01   0.03   0.09   0.08
# 443   0.01   0.03  0.02  0.01  0.01   0.02   0.05   0.08
# 1945  0.02   0.03  0.01  0.02  0.01   0.03   0.08   0.12

# %%
df_religion.head(20)
# Out:
#                                                    text  label  여성/가족    남성  \
# 404   아니 왜 그러는지는 알긴 알겠지만 종교 전도하듯이 예수천국 불신지옥 처럼 소신투표 ...      0   0.01  0.01
# 3100  왜냐면 그냥 없어지거든요 그냥 없는 존재 취급되는 거예요 엇 너무 익숙한데 교회 안...      0   0.01  0.02
# 1641  모르것다 소드나 맘카페에 신천지 존나 많아서 막 소신투표 하게끔 몰아붙인다던데 하 ...      0   0.01  0.00
# 1570  안철수가 휴대폰 사용 못하는 이유 폭력배 양아치 윤석열 대깨윤들의 문자폭탄 2만통 ...      1   0.05  0.01
# 752   아니쉬발 회유를 해도 설득이 될까말까 공격을 하면 어떡해요 다짜고짜 신천지 이 난리...      0   0.01  0.01
# 1500  구적폐 신적폐 양당적폐의 안철수 죽이기는 5년전이나 지금이나 똑같다 적폐에 줄선 기...      1   0.02  0.01
# 663   이재명을 소신투표 하겠냐 말 되는 소리를 해야지 마음 같아서는 이번 대선후보들 싹 ...      0   0.01  0.03
# 159   송시인이 임신 7개월었을 때 폭행해서 입원시킨 상습폭행범 배인규가 여혐이 아니라고 ...      0   0.01  0.02
# 2869  이재명도 개 민폐지 이재명이 진작에 압도적으로 이길만하게 빌드업 했어야 소신투표할사...      0   0.01  0.01
# 1108  찢빠들은 심상정 지지자들이 이재명찍으면 선거 이길수 있다고 생각하나보네 ㅋㅋㅋㅋ 팩...      0   0.16  0.01
# 599                       그렇다고 윤석열한테 소신투표를 어케함 대깨문 아닌이상      0   0.11  0.00
# 1048  이재명 존나 심각한 게 대선후보라는 게 임산부 배려석 자체를 모르고 있었음 임산부석...      0   0.01  0.01
# 574   이재명이 어느정도 수준이냐면 살인미수 음주운전 해놓고 문제되니까 2005년 농협불법...      0   0.01  0.00
# 1859  #안철수 #소신투표 강성 귀족노조 혁파 고용세습 타파 노동이사제 시행 전면보류 타임...      1   0.04  0.00
# 2477  가뜩이나 시벌 김동연 뽑고 싶었는데 좆같이 이재명이랑 단일화해서 강제로 소신투표도 ...      0   0.03  0.01
# 98    소신투표한다고 심상정 찍으면 절대 안 되겠다 윤석열이 대통령인 나라에서 절대 살고 ...      0   0.02  0.01
# 3037  페미니즘을 대하는 거대양당의 태도는 전라도를 대하는 태도를 보면 거의 똑같습니다 국...      0   0.28  0.02
# 1489  멍청한 2번 교활한 1번 보다 똑똑하고 선량한 안철수가 백배천배 낫다 #안철수대통령...      1   0.01  0.00
# 1488  멍청한 2번 교활한 1번 보다 똑똑하고 선량한 안철수가 백배천배 낫다 #안철수대통령...      1   0.01  0.00
# 1254  본인들 딴에는 소신투표의 위험성 이랍시고 소신투표탓으로 몰아가려는 의도였겠으나 그때...      0   0.06  0.01
#
#       성소수자  인종/국적    연령    지역    종교  기타 혐오  악플/욕설  clean
# 404   0.03   0.04  0.01  0.02  0.87   0.03   0.06   0.07
# 3100  0.04   0.01  0.01  0.01  0.15   0.01   0.06   0.68
# 1641  0.02   0.03  0.00  0.02  0.10   0.03   0.15   0.16
# 1570  0.03   0.18  0.04  0.02  0.09   0.54   0.16   0.04
# 752   0.02   0.03  0.01  0.02  0.08   0.02   0.72   0.03
# 1500  0.02   0.13  0.02  0.07  0.07   0.53   0.31   0.04
# 663   0.03   0.71  0.01  0.02  0.07   0.05   0.13   0.01
# 159   0.05   0.09  0.00  0.04  0.06   0.04   0.03   0.17
# 2869  0.01   0.04  0.00  0.06  0.06   0.06   0.55   0.04
# 1108  0.01   0.04  0.01  0.05  0.06   0.25   0.36   0.08
# 599   0.01   0.05  0.04  0.07  0.05   0.38   0.22   0.07
# 1048  0.01   0.02  0.00  0.02  0.05   0.02   0.29   0.22
# 574   0.02   0.03  0.01  0.02  0.05   0.10   0.65   0.07
# 1859  0.02   0.07  0.01  0.02  0.04   0.24   0.21   0.14
# 2477  0.01   0.04  0.01  0.08  0.04   0.07   0.78   0.02
# 98    0.01   0.03  0.01  0.02  0.04   0.05   0.83   0.03
# 3037  0.03   0.06  0.02  0.92  0.03   0.10   0.05   0.03
# 1489  0.03   0.03  0.01  0.19  0.03   0.12   0.31   0.06
# 1488  0.03   0.03  0.01  0.19  0.03   0.12   0.31   0.06
# 1254  0.01   0.04  0.03  0.04  0.03   0.40   0.41   0.04

# %%
df_man.head(20)
# Out:
#                                                    text  label  여성/가족    남성  \
# 2400                                한남에서 소신투표하는 한국남자강동원      0   0.05  0.94
# 2312  2번남들 부들대는게 보기 재밌긴한데 ㅋㅋ 헤테로 한남녀들의 싸움이라 뵈지도않고 모여...      0   0.06  0.94
# 942   이재명 고려하고 있는 이유는 간단함 한남충과 반대로 가기 위해서임 그들에게 제일 좆...      0   0.06  0.93
# 755   하 소신투표 할라고 진짜 맘 먹었었는데 나라가 왜 이 모양이 됐냐 눈물난다 어디 해...      0   0.03  0.93
# 863               윤석열이 당선되도 소신투표 주장하는 사람들은 왜 거의 다 한남들이냐      0   0.06  0.93
# 747   최소한 여성분들 지금의 생활을 유지하려면 찢을 뽑아야 합니다 한남들 지금 여기저기에...      0   0.06  0.93
# 301   한남충들이 여초 커뮤 들어가서 소신투표하자며 이재명 안 뽑게 선동해서 윤 되게 하려...      0   0.05  0.93
# 2499  자지새끼들 성상납준석 존나 부둥부둥해주더라 ㅋㅋㅋㅋㅋㅋㅋ 난 가세연이 이준석 성상납...      0   0.03  0.93
# 2325             난 전략맞음 입찢어져도 1번이 소신투표될순없어나한텐ㅋㅋㅋ 망할2번남들      0   0.03  0.92
# 3218  아직도 소신투표 타령하는거 솔직히 존나 짜증난다 소신투표의 결과가 여자표 무시하는거...      0   0.06  0.92
# 1657  한남들은 소신투표가 아니라 전략투표로 이재명을 뽑아서 여성인권과 페미의 입지가 넓어...      1   0.10  0.91
# 1066  이재명이 지금의 부인 김혜경에게 프로포즈하며 보여준 일기장 낮에 옥상에서 노는데 그...      1   0.07  0.91
# 2556  안그래도 지금 이 순간에도 소신투표할까 한남들 표를 내 표호 상쇄해야 하나 고민중이...      0   0.05  0.91
# 1391                          진짜 정치 한남들 ㅈ같아서 소신투표도 못하겠다      0   0.05  0.91
# 2974                  이번 선거에서 한남의 소신투표는 정당화될 수 없다고 생각해요      1   0.05  0.91
# 224   얘들아기억하자 소신투표안된다 나도심이좋지만지금은아님 이대남들이지랄발광여가부폐지에북다...      0   0.08  0.90
# 1013  걍 표분산 되는 게 윤석열 지지하는 펨코야갤 한남충들이 젤 원하는 건데 왜 아직까지...      0   0.12  0.90
# 1473                응소신투표할때가아니야 2제명 안 뽑으면 펨코남들의 시대가 온다고      0   0.04  0.90
# 804   윤 이 둘다 싫어서 소신투표하거나 표 던질랬는데 생각해보니 그러면 표 분산돼서 윤 ...      0   0.09  0.90
# 1050  이재명 아들이 친할머니 발인 다음날 시발 내상 입었다 는 은어가 섞인 성매매 업소 ...      0   0.05  0.90
#
#       성소수자  인종/국적    연령    지역    종교  기타 혐오  악플/욕설  clean
# 2400  0.02   0.05  0.03  0.03  0.02   0.02   0.05   0.05
# 2312  0.03   0.07  0.03  0.02  0.02   0.02   0.05   0.04
# 942   0.02   0.05  0.03  0.02  0.02   0.02   0.04   0.04
# 755   0.02   0.05  0.03  0.02  0.02   0.02   0.05   0.04
# 863   0.02   0.02  0.03  0.03  0.02   0.02   0.05   0.04
# 747   0.02   0.04  0.03  0.02  0.02   0.02   0.05   0.04
# 301   0.02   0.03  0.05  0.02  0.02   0.02   0.05   0.04
# 2499  0.03   0.05  0.04  0.02  0.02   0.03   0.05   0.03
# 2325  0.03   0.05  0.03  0.03  0.01   0.02   0.05   0.04
# 3218  0.02   0.02  0.04  0.02  0.02   0.02   0.06   0.04
# 1657  0.02   0.03  0.02  0.02  0.02   0.02   0.04   0.04
# 1066  0.02   0.04  0.02  0.02  0.02   0.02   0.07   0.06
# 2556  0.02   0.03  0.03  0.03  0.01   0.01   0.05   0.05
# 1391  0.02   0.03  0.04  0.02  0.02   0.02   0.06   0.04
# 2974  0.02   0.04  0.02  0.02  0.02   0.02   0.05   0.06
# 224   0.04   0.03  0.02  0.02  0.01   0.03   0.06   0.04
# 1013  0.02   0.02  0.04  0.02  0.02   0.02   0.04   0.05
# 1473  0.08   0.06  0.02  0.02  0.01   0.02   0.05   0.06
# 804   0.02   0.03  0.04  0.02  0.02   0.03   0.04   0.03
# 1050  0.02   0.03  0.04  0.02  0.01   0.02   0.06   0.04

# %%
df_region.head(20)
# Out:
#                                                    text  label  여성/가족    남성  \
# 3037  페미니즘을 대하는 거대양당의 태도는 전라도를 대하는 태도를 보면 거의 똑같습니다 국...      0   0.28  0.02
# 2360                        소신투표하는 사람들 1일 경상도 체험시켜주고 싶다      0   0.01  0.02
# 1635  2월 27일 일 안철수 후보님 호남유세 일정 09 30 목포역 광장 전남 목포시 영...      1   0.02  0.02
# 2481  대구 사람들에게 소신 투표를 하라고 하면 누구를 찍을 거 같냐 ㅋㅋㅋㅋ 내가 대구에...      0   0.01  0.01
# 2324  선거에서 투표 집계하는 자가 뽑히면 후진국 독재 대통령 여론조사서 이길 사람 뽑으면...      0   0.01  0.01
# 738   솔직히 문국현 뽑은 후로 한번도 소신 투표 해본적 없음 그냥 항상 차악 최악은 아니...      0   0.01  0.01
# 2972  댓글중 호남에서 소신투표가 많이 나타나리라고 본다 민주당후보이면 장작개비를 세워놔도...      0   0.01  0.01
# 513   ㅎ 충청쪽이란 말이죠 하여간 이 인간들이 하는 수 없군 정치정적의 힘을 무효화하기 ...      0   0.01  0.01
# 1401          대구 민심 정권은 바뀌어야 하는데 윤석열은 아니다 싶다 #안철수 #소신투표      1   0.01  0.01
# 442   선거 망한다고 딱히 소신투표한 사람들이 미워지진 않을거같은데 솔직히 서울영남중상류층...      0   0.04  0.06
# 3356  그놈의 배운여자 타령도 오히려 못배워 먹어서 콤플렉스인가 싶을 정도ㅋㅋ 1 2 둘다...      0   0.21  0.02
# 2027                     타루 전라에 소신투표했는데 의외로 표많아서 놀랬어요 ㅋ      1   0.01  0.01
# 1555  구안빠들 이런 표현도 싫다 소신투표니까 자기가 더 좋은 사람 찍는것이니 우리쪽에선 ...      0   0.01  0.02
# 1587  오렌지혁명 안풍이 부산 서울을 거쳐 광주에 상륙한다 호남 오렌지군단 많은 참여 기대...      1   0.01  0.01
# 3059  진짜 농담 아니고 윤 이 아니라 홍 그인간이 기호2번으로 나왔으면 내가 전략투표 이...      0   0.01  0.01
# 97    호랑이파 vs 고양이파 투표도 진행 중이던데 제가 마지막으로 봤을 때는 고양이가 이...      1   0.02  0.02
# 1634  안철수 호남유세 일정 오렌지군단은 호남 현장 유세에 함께 하면 좋겠다 오렌지혁명 안...      1   0.01  0.01
# 2242  대선철이라 이야기 많이 하는거라 이해 부탁해 칭구들 칭구들의 개인적인 정치성향에는 ...      0   0.01  0.01
# 2016                    팡푸가 입에 착 붙고 귀여웠지만 딪푸에 소신 투표 한 나      1   0.01  0.01
# 1079  우아한 터프녀 ㅋㅋ 올림픽 2연패와 최민정 금메달 이유빈 취민정 그리고 팀킴 너무 ...      1   0.06  0.05
#
#       성소수자  인종/국적    연령    지역    종교  기타 혐오  악플/욕설  clean
# 3037  0.03   0.06  0.02  0.92  0.03   0.10   0.05   0.03
# 2360  0.02   0.02  0.01  0.86  0.01   0.02   0.05   0.09
# 1635  0.02   0.03  0.01  0.82  0.02   0.02   0.03   0.34
# 2481  0.01   0.03  0.01  0.75  0.02   0.02   0.06   0.13
# 2324  0.02   0.17  0.02  0.74  0.01   0.08   0.06   0.04
# 738   0.01   0.02  0.01  0.72  0.01   0.02   0.08   0.19
# 2972  0.01   0.03  0.01  0.71  0.01   0.02   0.05   0.21
# 513   0.01   0.02  0.01  0.57  0.01   0.03   0.28   0.09
# 1401  0.02   0.02  0.01  0.51  0.01   0.02   0.04   0.33
# 442   0.03   0.04  0.02  0.51  0.00   0.02   0.03   0.36
# 3356  0.01   0.02  0.02  0.49  0.01   0.03   0.10   0.08
# 2027  0.01   0.02  0.01  0.40  0.01   0.01   0.05   0.61
# 1555  0.01   0.02  0.01  0.33  0.01   0.04   0.34   0.07
# 1587  0.01   0.02  0.01  0.32  0.01   0.02   0.04   0.57
# 3059  0.01   0.02  0.01  0.31  0.01   0.02   0.35   0.08
# 97    0.02   0.04  0.01  0.31  0.01   0.01   0.03   0.65
# 1634  0.01   0.02  0.01  0.30  0.02   0.02   0.03   0.72
# 2242  0.02   0.04  0.01  0.30  0.01   0.01   0.03   0.71
# 2016  0.01   0.11  0.01  0.29  0.01   0.01   0.04   0.46
# 1079  0.02   0.04  0.01  0.26  0.01   0.01   0.03   0.29

# %%
df_queer.head(20)
# Out:
#                                                    text  label  여성/가족    남성  \
# 1672  퀴어 인권 개판되는거 알죠 저희는 mb랑 ㄹ혜 10년을 다시 겪고 싶지 않으니까 도...      0   0.02  0.01
# 1791  여성으로써 성소수자로써 이나 윤이나 누가 뽑혀도 개좆같고 지옥같고 모멸감 드는건 매...      0   0.07  0.01
# 1364  무지 개판 인간들은 걍 소신 투표하세요 페미니즘으로 쓰까 먹는거 이제 그만하시고 소...      0   0.10  0.01
# 1789  심 소신투표 하겠다는 사람들 코너로 몰고 그 표 앞에서 여성인권 성소수자인권 외치면...      0   0.07  0.01
# 785   윤석열이 당선되면 차별금지법커녕 장애인들의 집회는 경찰의 폭력으로 막히고 성소수자 ...      0   0.08  0.02
# 1834  지금 이 찍겠다는 사람들이 누구보다도 절박한 거 아닌가 누군 소신투표 안 하고 싶어...      0   0.03  0.01
# 2434  소신투표하고 싶다 근데 죽어도 소수자 혐오를 프레임으로 들고온 후보가 뽑히는 꼴은 ...      1   0.03  0.02
# 1822  이재명이 안되면 성소수자가 소신투표해서가 아니라 당과 후보의 자질과 전략이 부족했던...      0   0.02  0.01
# 1825  민주당 당선이 불확실할때는 전략투표하고 확실할 때는 소신투표 하라는건가 그럼 민주당...      0   0.03  0.01
# 583   사실 퀴어 여성 챙기겠다고 말만해도 소신투표로 나뉠거없이 표 받게될텐데 소신투표로 ...      0   0.03  0.01
# 1280  김재연후보는 국민의 엄마가 되겠다고 모성을 판 적도 없고 성소수자코인 땡겼다가 통수...      0   0.02  0.01
# 2735  당연히 국민의힘이 그 꼬라지 를 하고도 계속 꾸준히 기세가 이어가는 건 양당제의 수...      0   0.02  0.01
# 2170            이번에도 소신투표 할랍니다 왜냐고 퀴어얘기해주는 주후보가 그사람뿐입니다      1   0.02  0.01
# 281   전략투표와 소신투표 사이에서 계속 고민중인데 성소수자에 대한 견해와 더불어 약자에 ...      0   0.02  0.01
# 1756  소신투표야 본인 자유지만 윤석열이 당선될 확률에도 불구하고 꿋꿋이 신념을 지키는 나...      0   0.01  0.01
# 861   나도 저번대선에서 그랬지만 소신투표하시는 분들은 지지율 1 2위 두사람 중 누가돼도...      1   0.02  0.01
# 2979  어쩌구 저쩌구 해서 너네 소수자 는 소신 투표하지 말아야 한다는 말 보면 그냥 코웃...      0   0.01  0.01
# 2074  6 등급 2022 제 1회 모의고사 말랑말랑편 퀴즈도 풀고 만들기까지 #내가만드는퀴...      1   0.02  0.02
# 1850  지난 민주당새끼 동성애 반대합니다 예예 나중에 5년지남 다음 민주당새끼 희망사항ㅋㅋ...      0   0.02  0.01
# 936                      트민쟁이들이 재수없게 구니까 다들 소신투표 하려고 하네      0   0.03  0.03
#
#       성소수자  인종/국적    연령    지역    종교  기타 혐오  악플/욕설  clean
# 1672  0.81   0.02  0.01  0.02  0.01   0.04   0.08   0.10
# 1791  0.79   0.01  0.01  0.01  0.01   0.08   0.13   0.07
# 1364  0.77   0.01  0.01  0.01  0.01   0.06   0.09   0.07
# 1789  0.76   0.01  0.01  0.02  0.01   0.11   0.07   0.08
# 785   0.76   0.04  0.03  0.04  0.01   0.48   0.08   0.05
# 1834  0.73   0.02  0.01  0.01  0.01   0.03   0.08   0.09
# 2434  0.72   0.02  0.01  0.02  0.01   0.18   0.11   0.08
# 1822  0.70   0.01  0.01  0.01  0.02   0.04   0.07   0.12
# 1825  0.66   0.01  0.01  0.02  0.01   0.04   0.10   0.13
# 583   0.65   0.02  0.01  0.01  0.01   0.02   0.07   0.19
# 1280  0.59   0.01  0.01  0.01  0.01   0.04   0.09   0.16
# 2735  0.58   0.02  0.01  0.01  0.01   0.02   0.06   0.28
# 2170  0.57   0.02  0.01  0.01  0.01   0.02   0.06   0.28
# 281   0.56   0.01  0.01  0.01  0.01   0.02   0.05   0.30
# 1756  0.55   0.01  0.01  0.01  0.02   0.10   0.11   0.15
# 861   0.46   0.02  0.01  0.01  0.01   0.02   0.08   0.37
# 2979  0.41   0.01  0.01  0.01  0.01   0.05   0.17   0.13
# 2074  0.39   0.02  0.01  0.01  0.01   0.01   0.07   0.50
# 1850  0.38   0.01  0.01  0.07  0.01   0.06   0.25   0.04
# 936   0.37   0.34  0.01  0.01  0.01   0.09   0.13   0.03

# %%
# 0.6이상인 텍스트들만 추출
df_woman = df_woman[df_woman['여성/가족'] >= 0.6]
df_man = df_man[df_man['남성'] >= 0.6]
df_region = df_region[df_region['지역'] >= 0.6]
df_queer = df_queer[df_queer['성소수자'] >= 0.6]
df_religion = df_religion[df_religion['종교'] >= 0.6]

# %%
# 전체 갯수 확인
print(len(df_woman))
print(len(df_man))
print(len(df_region))
print(len(df_queer))
print(len(df_religion))
# Out:
# 119
# 52
# 7
# 10
# 1

# %%
print('여성/가족 긍정 리뷰 갯수: {}'.format(df_woman['label'].value_counts()[1]))
print('여성/가족 부정 리뷰 갯수: {}'.format(df_woman['label'].value_counts()[0]))
print('남성 긍정 리뷰 갯수: {}'.format(df_man['label'].value_counts()[1]))
print('남성 부정 리뷰 갯수: {}'.format(df_man['label'].value_counts()[0]))
print('지역 긍정 리뷰 갯수: {}'.format(df_region['label'].value_counts()[1]))
print('지역 부정 리뷰 갯수: {}'.format(df_region['label'].value_counts()[0]))
print('성소수자 긍정 리뷰 갯수: {}'.format(df_queer['label'].value_counts()[1]))
print('성소수자 부정 리뷰 갯수: {}'.format(df_queer['label'].value_counts()[0]))
#print('종교 긍정 리뷰 갯수: {}'.format(df_religion['label'].value_counts()[1]))
print('종교 부정 리뷰 갯수: {}'.format(df_religion['label'].value_counts()[0]))
# Out:
# 여성/가족 긍정 리뷰 갯수: 4
# 여성/가족 부정 리뷰 갯수: 115
# 남성 긍정 리뷰 갯수: 5
# 남성 부정 리뷰 갯수: 47
# 지역 긍정 리뷰 갯수: 1
# 지역 부정 리뷰 갯수: 6
# 성소수자 긍정 리뷰 갯수: 1
# 성소수자 부정 리뷰 갯수: 9
# 종교 부정 리뷰 갯수: 1

# %%
# 긍정, 부정 분포도
def posNneg(df):
    label = ['positive', 'negative']
    index =  np.arange(len(df['label']))
    value = [df['label'].value_counts()[1], df['label'].value_counts()[0]]
    value = [0, df['label'].value_counts()[0]]
    plt.bar(label, value, color=['r', 'b'], alpha=0.5)
    plt.title('Distribution of Pos and Neg', fontsize=15)
    plt.xlabel('label')
    plt.ylabel('count')
    plt.show()

# %%
# 백업용 저장
df_woman.to_csv('./CrawledData/소신투표/소신투표_여성.csv', encoding='utf-8-sig',sep=',', index=False)
df_man.to_csv('./CrawledData/소신투표/소신투표_남성.csv', encoding='utf-8-sig',sep=',', index=False)
df_region.to_csv('./CrawledData/소신투표/소신투표_지역.csv', encoding='utf-8-sig',sep=',', index=False)
df_queer.to_csv('./CrawledData/소신투표/소신투표_성소수자.csv', encoding='utf-8-sig',sep=',', index=False)
df_religion.to_csv('./CrawledData/소신투표/소신투표_종교.csv', encoding='utf-8-sig',sep=',', index=False)

# %%
df_woman = pd.read_csv('./CrawledData/소신투표/소신투표_여성.csv', encoding='utf-8')
df_man = pd.read_csv('./CrawledData/소신투표/소신투표_남성.csv', encoding='utf-8')
df_region = pd.read_csv('./CrawledData/소신투표/소신투표_지역.csv', encoding='utf-8')
df_queer = pd.read_csv('./CrawledData/소신투표/소신투표_성소수자.csv', encoding='utf-8')
df_religion=pd.read_csv('./CrawledData/소신투표/소신투표_종교.csv', encoding='utf-8')

# %%
import re

# Basic Cleaning Text Function
def CleanText(readData, Num=False, Eng=False):

    # Remove Retweets RT @user_screenname 
    text = re.sub('RT @[\w_]+: ', '', readData)
    text = re.sub('알티', '', text)
    text = re.sub('RT', '', text)

    # Remove Mentions
    text = re.sub('@[\w_]+', '', text)

    # Remove or Replace URL 
    text = re.sub(r"http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+", ' ', text) # http로 시작되는 url
    text = re.sub(r"[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{2,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)", ' ', text) # http로 시작되지 않는 url
    
    # Remove Hashtag
    text = re.sub('[#]+[0-9a-zA-Z_]+', ' ', text)

    # Remove Garbage Words (ex. &lt, &gt, etc)
    text = re.sub('[&]+[a-z]+', ' ', text)

    # Remove Special Characters
    text = re.sub('[^0-9a-zA-Zㄱ-ㅎ가-힣]', ' ', text)
    
    # Remove newline
    text = text.replace('\n',' ')
    
    if Num is True:
        # Remove Numbers
        text = re.sub(r'\d+',' ',text)
    
    if Eng is True:
        # Remove English 
        text = re.sub('[a-zA-Z]' , ' ', text)

    # Remove multi spacing & Reform sentence
    text = ' '.join(text.split())
       
    return text

# %%
from konlpy.tag import Mecab

# %%
# Preprocessing code with Mecab
#dicpath="/usr/local/lib/mecab/dic/mecab-ko-dic"
mecab = Mecab(r"C:/mecab/mecab-ko-dic") # Mecab User Dic Path

def preprocessing_mecab(readData):
    
    #### Clean text
    sentence = CleanText(readData)
    
    #### Tokenize
    morphs = mecab.pos(sentence)
    
    JOSA = ["JKS", "JKC", "JKG", "JKO", "JKB", "JKV", "JKQ", "JX", "JC"] # 조사
    SIGN = ["SF", "SE", "SSO", "SSC", "SC", "SY"] # 문장 부호
    TERMINATION = ["EP", "EF", "EC", "ETN", "ETM"] # 어미
    SUPPORT_VERB = ["VX"] # 보조 용언
    NUMBER = ["SN"]
    
    # Remove JOSA, EOMI, etc
    morphs[:] = (morph for morph in morphs if morph[1] not in JOSA+SIGN+TERMINATION+SUPPORT_VERB)
        
    # Remove length-1 words  
    morphs[:] = (morph for morph in morphs if not (len(morph[0]) == 1))
    
    # Remove Numbers
    morphs[:] = (morph for morph in morphs if morph[1] not in NUMBER)
   
    # Result pop-up
    result = []
    for morph in morphs:
        result.append(morph[0])
        
    return result

# %%
df_woman['tokenized'] = df_woman['text'].apply(lambda x: preprocessing_mecab(x))
df_man['tokenized'] = df_man['text'].apply(lambda x: preprocessing_mecab(x))
df_region['tokenized'] = df_region['text'].apply(lambda x: preprocessing_mecab(x))
df_queer['tokenized'] = df_queer['text'].apply(lambda x: preprocessing_mecab(x))
df_religion['tokenized'] = df_religion['text'].apply(lambda x: preprocessing_mecab(x))

# %%
token_woman = df_woman['tokenized']
token_man = df_man['tokenized']
token_region = df_region['tokenized']
token_queer = df_queer['tokenized']
token_religion = df_religion['tokenized']

# %%
# tokenizing
# stopwords list
stop_words = pd.read_csv('./한국어불용어100.txt', sep = "\t", engine='python')
stop_words = list(stop_words["word"])
stopwords = ['한다', '세요', '합니다', '입니다', 'ㅋㅋㅋ', 'ㅋㅋ','소신', '투표', '진짜', '아니', '근데', '그냥', '라고', '한다고', '해서', '이런', '어차피', '버리', '된다는','생겼', '인데', '해도', '된다', '이거', ]
stopwords = stopwords+stop_words
stopwords.remove('여자')

# %%
print(stopwords)
# Out:
# ['한다', '세요', '합니다', '입니다', 'ㅋㅋㅋ', 'ㅋㅋ', '소신', '투표', '진짜', '아니', '근데', '그냥', '라고', '한다고', '해서', '이런', '어차피', '버리', '된다는', '생겼', '인데', '해도', '된다', '이거', '이', '있', '하', '것', '들', '그', '되', '수', '이', '보', '않', '없', '나', '사람', '주', '아니', '등', '같', '우리', '때', '년', '가', '한', '지', '대하', '오', '말', '일', '그렇', '위하', '때문', '그것', '두', '말하', '알', '그러나', '받', '못하', '일', '그런', '또', '문제', '더', '사회', '많', '그리고', '좋', '크', '따르', '중', '나오', '가지', '씨', '시키', '만들', '지금', '생각하', '그러', '속', '하나', '집', '살', '모르', '적', '월', '데', '자신', '안', '어떤', '내', '내', '경우', '명', '생각', '시간', '그녀', '다시', '이런', '앞', '보이', '번', '나', '다른', '어떻', '개', '전', '들', '사실', '이렇', '점', '싶', '말', '정도', '좀', '원', '잘', '통하', '소리', '놓']

# %%
category = [token_woman, token_man, token_region, token_queer, token_religion]
title = ['여성/가족', '남성', '지역', '성소수자', '종교']

# %%
# 단어 빈도수 생성
def word_frequency(token, title):
    n_corpus = []
    for t in token:
        for j in t:
            if j not in stopwords:
                n_corpus.append(j)

    count = collections.Counter(n_corpus) 
    most = count.most_common() # 빈도 수 순으로 추출 
    x, y= [], [] 
    for word,count in most[:40]: 
        x.append(word) 
        y.append(count)
    #plt.rc('font',family='NanumGothic.ttf')
    plt.rcParams['font.family'] = "NanumGothic"
    plt.rcParams['axes.unicode_minus'] = False
    plt.figure(figsize=(10,10)) 
    sns.barplot(x=y,y=x)
    plt.title(title)

# %%
# 여성/가족, 남성, 지역, 성소수자, 종교
for c, t in zip(category, title):
    word_frequency(c, t)

# %%
# 워드 클라우드 생성
def make_wordcloud(token, title):
    n_corpus = []
    for t in token:
        for j in t:
            if j not in stopwords:
                n_corpus.append(j)
    font_path = 'C:/Users/Erin/AppData/Local/Microsoft/Windows/Fonts/NanumGothic.ttf'
    wordcloud = WordCloud(font_path=font_path,
                        background_color="black",
                        stopwords=stopwords, 
                        max_words=100, 
                        # max_font_size=30,
                        width=500,
                        height=500, 
                        random_state=1,
                        scale=3).generate(' '.join(n_corpus))
    fig = plt.figure(1, figsize=(8,8)) 
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title)
    plt.show()

# %%
for c, t in zip(category, title):
    make_wordcloud(c, t)
